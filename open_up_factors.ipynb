# %%
import pandas as pd

# %%
df0 = pd.read_excel('factor_model_data.xlsx', sheet_name=0)

# %%
df0
# Out:
#                 benchmarkId   asOfDate                 model           factor  \
# 0      37287US_IMI_AERODFNS 2002-01-31  US_IMI                US_IMI_AERODFNS
# 1       37287US_IMI_AIRLINE 2002-01-31  US_IMI                 US_IMI_AIRLINE
# 2       37287US_IMI_APPAREL 2002-01-31  US_IMI                 US_IMI_APPAREL
# 3      37287US_IMI_AUTOCOMP 2002-01-31  US_IMI                US_IMI_AUTOCOMP
# 4         37287US_IMI_BANKS 2002-01-31  US_IMI                   US_IMI_BANKS
# ...                     ...        ...                   ...              ...
# 15415  44344US_IMI_SOFTWARE 2021-05-28  US_IMI                US_IMI_SOFTWARE
# 15416  44344US_IMI_SPCLRETL 2021-05-28  US_IMI                US_IMI_SPCLRETL
# 15417  44344US_IMI_TELECOMM 2021-05-28  US_IMI                US_IMI_TELECOMM
# 15418  44344US_IMI_TRANSPRT 2021-05-28  US_IMI                US_IMI_TRANSPRT
# 15419  44344US_IMI_TRDGCOMP 2021-05-28  US_IMI                US_IMI_TRDGCOMP
#
# ...

# %%
type(df0['asOfDate'].dtype)
# Out:
# numpy.dtype[datetime64]

# %%
print(len(pd.unique(df0.asOfDate)))
print(df0.asOfDate.dt.date.max(), df0.asOfDate.dt.date.min())
# Out:
# 232
# 2021-05-28 2002-01-31
